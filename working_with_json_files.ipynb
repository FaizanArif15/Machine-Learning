# %%
import pandas as pd

# %%
df = pd.read_json("/content/OYO.json")

# %%
df.head()
# Out:
#                                          NAME  \
# 0               OYO Flagship SATYAM INN LODGE
# 1            OYO Flagship 39898 Hotel Raj Inn
# 2  OYO Flagship 46691 Jaldapara Rhino Resort
# 3                       OYO 45569 Goyal's Inn
# 4                       OYO Sandhana Homestay
#
#                                              ADDRESS RATING  RATED BY  \
# 0  5-11-51/41D Near New Bus Stand Beside Maruti M...   3.7        3.0
# 1  0, Near AIT college, Pushkar BypassNear AIT Co...   4.0       30.0
# 2  Plot- 1, Block- 3, Purba Khairbari, Kharibari,...   5.0        1.0
# 3  C-19 & 20-s, Opp Water Tank Near Glitz Cinema ...   3.7       12.0
# 4                   Sh16, Paschim Jitpur, Alipurduar   3.6        6.0
#
#   BASE_COST FINAL_COST                                           AMENITYS  \
# 0      ₹916     ₹1068                                      [WiFi, AC, TV]
# 1      ₹733      ₹861   [AC, Free Wifi, Kitchen, TV, Power backup, Gey...
# ...
