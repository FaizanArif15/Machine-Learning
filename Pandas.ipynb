# %% [markdown]
# Import Pandas Library in Python

# %%
import pandas as pd

# %% [markdown]
# Read CSV file

# %%
df = pd.read_csv("/content/winequality-red.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b81ac437f971> in <cell line: 1>()
# ----> 1 df = pd.read_csv("/content/winequality-red.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Show First 5 Rows

# %%
# df.head(9)
# df.head(3)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# Show Last 5 Rows

# %%
# df.tail(2)
# df.tail(7)
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %% [markdown]
# Show All Information About Features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# Show Rows and Columns in tuple from Dataset

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# Fetching Different Types of Data from Dataset using Different Techniques

# %%
df["citric acid"]
# Out:
# 0       0.00
# 1       0.00
# 2       0.04
# 3       0.56
# 4       0.00
#         ...
# 1594    0.08
# 1595    0.10
# 1596    0.13
# 1597    0.12
# 1598    0.47
# Name: citric acid, Length: 1599, dtype: float64

# %%
df[['chlorides','density']].head()
# Out:
#    chlorides  density
# 0      0.076   0.9978
# 1      0.098   0.9968
# 2      0.092   0.9970
# 3      0.075   0.9980
# 4      0.076   0.9978

# %%
df.iloc[2:6]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5

# %%
df.iloc[15:25:3,[3,1,8,7]]
# Out:
#     residual sugar  volatile acidity    pH  density
# 15             3.9              0.62  3.17   0.9986
# 18             4.4              0.59  3.38   0.9974
# 21             2.3              0.39  3.52   0.9982
# 24             2.4              0.40  3.43   0.9968

# %%
df.iloc[[15,25,20,100],[11]].shape
# Out:
# (4, 1)

# %% [markdown]
# Masking using Boolean Series

# %%
mask1 = df['citric acid']> 0.5
df[mask1].shape[0]
# Out:
# 190

# %%
mask2 = df['pH']> 3.5
# df[mask2].shape[0]
# df[mask1 & mask2].shape[0]
df[mask1 & mask2]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 75             8.8              0.41         0.64             2.2      0.093
# 76             8.8              0.41         0.64             2.2      0.093
# 861            5.8              1.01         0.66             2.0      0.039
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 75                   9.0                  42.0  0.99860  3.54       0.66
# 76                   9.0                  42.0  0.99860  3.54       0.66
# 861                 15.0                  88.0  0.99357  3.66       0.60
#
#      alcohol  quality
# 75      10.5        5
# 76      10.5        5
# 861     11.5        6

# %% [markdown]
# The value_counts() method is used to count the frequency of each distinct data in a categorical series.

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# Sorting Techniques

# %%
df['quality'].value_counts(ascending=True)
# Out:
# 3     10
# 8     18
# 4     53
# 7    199
# 6    638
# 5    681
# Name: quality, dtype: int64

# %%
df['quality'].value_counts(ascending=True).tail()
# Out:
# 8     18
# 4     53
# 7    199
# 6    638
# 5    681
# Name: quality, dtype: int64

# %%
df.sort_values('density')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1017            8.0             0.180         0.37             0.9      0.049
# 1018            8.0             0.180         0.37             0.9      0.049
# 1114            5.0             0.400         0.50             4.3      0.046
# 836             6.7             0.280         0.28             2.4      0.012
# 837             6.7             0.280         0.28             2.4      0.012
# ...             ...               ...          ...             ...        ...
# 555            15.5             0.645         0.49             4.2      0.095
# 554            15.5             0.645         0.49             4.2      0.095
# 442            15.6             0.685         0.76             3.7      0.100
# 1435           10.2             0.540         0.37            15.4      0.214
# 1434           10.2             0.540         0.37            15.4      0.214
#
# ...

# %%
df.sort_values(['density','pH']).head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1017            8.0              0.18         0.37             0.9      0.049
# 1018            8.0              0.18         0.37             0.9      0.049
# 1114            5.0              0.40         0.50             4.3      0.046
# 836             6.7              0.28         0.28             2.4      0.012
# 837             6.7              0.28         0.28             2.4      0.012
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1017                 36.0                 109.0  0.99007  2.89       0.44
# 1018                 36.0                 109.0  0.99007  2.89       0.44
# 1114                 29.0                  80.0  0.99020  3.49       0.66
# 836                  36.0                 100.0  0.99064  3.26       0.39
# 837                  36.0                 100.0  0.99064  3.26       0.39
#
#       alcohol  quality
# 1017     12.7        6
# ...

# %%
df.sort_values(['density','pH'],ascending=[False,True]).head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1434           10.2             0.540         0.37            15.4      0.214
# 1435           10.2             0.540         0.37            15.4      0.214
# 442            15.6             0.685         0.76             3.7      0.100
# 554            15.5             0.645         0.49             4.2      0.095
# 555            15.5             0.645         0.49             4.2      0.095
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1434                 55.0                  95.0  1.00369  3.18       0.77
# 1435                 55.0                  95.0  1.00369  3.18       0.77
# 442                   6.0                  43.0  1.00320  2.95       0.68
# 554                  10.0                  23.0  1.00315  2.92       0.74
# 555                  10.0                  23.0  1.00315  2.92       0.74
#
#       alcohol  quality
# 1434      9.0        6
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# Sorted Order store in df variable using inplace=True parameter in sorted_values() method.

# %%
df.sort_values(['density','pH'],ascending=[False,True],inplace=True)
df.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1434           10.2             0.540         0.37            15.4      0.214
# 1435           10.2             0.540         0.37            15.4      0.214
# 442            15.6             0.685         0.76             3.7      0.100
# 554            15.5             0.645         0.49             4.2      0.095
# 555            15.5             0.645         0.49             4.2      0.095
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1434                 55.0                  95.0  1.00369  3.18       0.77
# 1435                 55.0                  95.0  1.00369  3.18       0.77
# 442                   6.0                  43.0  1.00320  2.95       0.68
# 554                  10.0                  23.0  1.00315  2.92       0.74
# 555                  10.0                  23.0  1.00315  2.92       0.74
#
#       alcohol  quality
# 1434      9.0        6
# ...
